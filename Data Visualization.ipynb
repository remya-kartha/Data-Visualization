# %%
# importing all the important libraries
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# loading the fifa data
fifa_data = pd.read_csv(r"fifa.csv",index_col='Date',parse_dates=True)

#displaying the first 5 rows of data
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# # Plotting the data

# %% [markdown]
# ## 1. Line Chart
# a line or multiple lines showing how single, or multiple variables develop over time.

# %%
# Setting the width and height of the figure
plt.figure(figsize=(16,5))

# Line chart showing how the FIFA rankings have evolved over time
sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Brazil is the only country to have spent atleast 5 consecutive years in 1st position

# %% [markdown]
# ### Museum Data Analysis- Line Chart

# %%
# loading the museum data
museum_data = pd.read_csv("museum_visitors.csv",index_col='Date',parse_dates=True)

#dispalying first 5 rows of the data
museum_data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %% [markdown]
# ### Convince the museum board
# The Firehouse Museum claims they ran an event in 2014 that brought an incredible number of visitors, and that they should get extra budget to run a similar event again. The other museums think these types of events aren't that important, and budgets should be split purely based on recent visitors on an average day.
#
# To show the museum board how the event compared to regular traffic at each museum, create a line chart that shows how the number of visitors to each museum evolved over time. Your figure should have four lines (one for each museum).

# %%
# displaying the line chart
plt.figure(figsize=(10,5))
sns.lineplot(data=museum_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Assess seasonality
# When meeting with the employees at Avila Adobe, you hear that one major pain point is that the number of museum visitors varies greatly with the seasons, with low seasons (when the employees are perfectly staffed and happy) and also high seasons (when the employees are understaffed and stressed). You realize that if you can predict these high and low seasons, you can plan ahead to hire some additional seasonal employees to help out with the extra work.
#
# Part A
# Create a line chart that shows how the number of visitors to Avila Adobe has evolved over time.

# %%
Avila_data = museum_data['Avila Adobe']

# plotting the number of visitors to Avila Adobe each year
plt.figure(figsize=(10,5))
sns.lineplot(data=Avila_data)
plt.title("Trend of visitors to Avila Adobe over the years")
# Out:
# Text(0.5, 1.0, 'Trend of visitors to Avila Adobe over the years')

# %% [markdown]
# The line chart generally dips to relatively low values around the early part of each year (in December and January), and reaches its highest values in the middle of the year (especially around May and June). Thus, Avila Adobe usually gets more visitors in March-August (or the spring and summer months). With this in mind, Avila Adobe could definitely benefit from hiring more seasonal employees to help with the extra work in March-August (the spring and summer)!

# %% [markdown]
# ## 2. Bar Chart
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. Can be of one variable or many variable.

# %% [markdown]
# ### IGN Game Reviews

# %% [markdown]
# ### Scenario
# You've recently decided to create your very own video game! As an avid reader of IGN Game Reviews, you hear about all of the most recent game releases, along with the ranking they've received from experts, ranging from 0 (Disaster) to 10 (Masterpiece).

# %%
# Loading the data
ign_filepath = "ign_scores.csv"
ign_data = pd.read_csv(ign_filepath,index_col='Platform')

# displaying all the data
ign_data
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
# What is the highest average score received by PC games,for any genre?
high_score = 7.759930

# On the Playstation Vita platform, which genre has the lowest average score? 
worst_genre = 'Simulation'

# %% [markdown]
# ### Which platform is best for Racing Games?

# %% [markdown]
# #### Create a bar chart that shows the average score for racing games, for each platform.

# %%
plt.figure(figsize=(16,8))
plt.title("Average Score for Racing Games Vs Platform")
sns.barplot(x=ign_data['Racing'],y=ign_data.index)
plt.ylabel = 'Platform'
plt.xlabel = 'Racing'

# %% [markdown]
# Based on the data, we should not expect a racing game for the Wii platform to receive a high rating. In fact, on average, racing games for Wii score lower than any other platform. Xbox One seems to be the best alternative, since it has the highest average ratings.

# %% [markdown]
# ## 3. Heat Map
# Heatmaps are used to show relationships between two variables, one plotted on each axis

# %% [markdown]
# #### Use the data to create a heatmap of average score by genre and platform.

# %%
plt.figure(figsize=(14,6))
plt.title("HeatMap showing relationship between 'Average Score by Genre' and 'Platform'")
sns.heatmap(data=ign_data,annot=True)
plt.show()

# %% [markdown]
# Simulation games for Playstation 4 receive the highest average ratings (9.2). Shooting and Fighting games for Game Boy Color receive the lowest average rankings (4.5).

# %% [markdown]
# ## 3. Scatter Plot
# A scatter plot is a great indicator that allows us to see whether there is a pattern to be found between two variables. E.g. : Positive or negative relationship.

# %% [markdown]
# ### Survey to Crowdsource Favorite Candies.

# %%
# Path of the file to read
candy_filepath = "candy.csv"

# Fill in the line below to read the file into a variable candy_data
candy_data = pd.read_csv(candy_filepath,index_col='id')

# %%
# Print the first five rows of the data
candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
candy_data.shape
# Out:
# (83, 13)

# %% [markdown]
# The dataset contains 83 rows, where each corresponds to a different candy bar. There are 13 columns

# %%
# Which candy was more popular with survey respondents?
(candy_data[candy_data['winpercent'] == candy_data['winpercent'].max()]).competitorname
# Out:
# id
# 50    Reese's Peanut Butter cup
# Name: competitorname, dtype: object

# %%
#Which candy has highest sugar content:
candy_data[candy_data['sugarpercent']==candy_data['sugarpercent'].max()]['competitorname']
# Out:
# id
# 52    Reese's stuffed with pieces
# Name: competitorname, dtype: object

# %% [markdown]
# #### The Role of Sugar

# %% [markdown]
# Do people tend to prefer candies with higher sugar content?Create a scatter plot that shows the relationship between 'sugarpercent' (on the horizontal x-axis) and 'winpercent' (on the vertical y-axis).

# %%
plt.title('Do people tend to prefer candy with higher sugar content ?')
sns.scatterplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
# Out:
# <AxesSubplot:title={'center':'Do people tend to prefer candy with higher sugar content ?'}, xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# The scatter plot does not show a strong correlation between the two variables. Since there is no clear relationship between the two variables, this tells us that sugar content does not play a strong role in candy popularity.

# %% [markdown]
# ## 4. Scatter Plot with Regression Line

# %%
plt.title('Do people tend to prefer candy with higher sugar content ?')
sns.regplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'])
# Out:
# <AxesSubplot:title={'center':'Do people tend to prefer candy with higher sugar content ?'}, xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between 'winpercent' and 'sugarpercent'. Thus, people have a slight preference for candies containing relatively more sugar.

# %% [markdown]
# ## 5. Color Coded Scatter Plot - with `'hue'` set
# Relationship between three variables

# %% [markdown]
# #### The Relationship between Chocolate, Winpercent and Pricepercent

# %% [markdown]
# In the code cell below, create a scatter plot to show the relationship between `'pricepercent'` (on the horizontal x-axis) and `'winpercent'` (on the vertical y-axis). Use the `'chocolate'` column to color-code the points.

# %%
sns.scatterplot(x=candy_data['sugarpercent'],y=candy_data['winpercent'],hue=candy_data['chocolate'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# ## 5. Color Coded Scatter Plot with Regression Line - lmplot

# %% [markdown]
# Scatter plot with two regression lines, corresponding to (1) chocolate candies and (2) candies without chocolate.

# %%
sns.lmplot(x='pricepercent',y='winpercent',hue='chocolate',data=candy_data)

# %% [markdown]
# Consider the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies).
# Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper.

# %% [markdown]
# ## 6. Categorical Scatter Plot - swarmplot

# %% [markdown]
# #### Relationship between Chocolate and Winpercent

# %%
sns.swarmplot(x=candy_data['chocolate'],y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# Chocolate candies tend to be more popular than candies without chocolate.

# %% [markdown]
# ## 7. Pie Chart

# %%
# loading the data
wine_path = "winemag-data_first150k.csv"
wine_review_data = pd.read_csv(wine_path,index_col=0)
wine_review_data.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
wine_review_data["total_value"] = wine_review_data.price + wine_review_data.points

# %%
wine_review_data['province'].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='province'>

# %% [markdown]
# ## 8.Donut Plot

# %%
wine_review_data['province'].value_counts().head(10).plot.pie()
circle = plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# ## 9.Histogram
# A series of bins showing us the frequency of observations of a given variable.

# %% [markdown]
# ### Analysis of Breast Cancer data

# %%
# Paths of the files to read
cancer_b_filepath = "cancer_b.csv"
cancer_m_filepath = "cancer_m.csv"

#reading the (benign) file into a variable cancer_b_data
cancer_b_data = pd.read_csv(cancer_b_filepath,index_col='Id')

# reading the (malignant) file into a variable cancer_mdata
cancer_m_data = pd.read_csv(cancer_m_filepath,index_col='Id')

# %%
cancer_b_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
cancer_m_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 842302           M          17.99           10.38            122.80
# 842517           M          20.57           17.77            132.90
# 84300903         M          19.69           21.25            130.00
# 84348301         M          11.42           20.38             77.58
# 84358402         M          20.29           14.34            135.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 842302         1001.0            0.11840             0.27760
# 842517         1326.0            0.08474             0.07864
# 84300903       1203.0            0.10960             0.15990
# 84348301        386.1            0.14250             0.28390
# 84358402       1297.0            0.10030             0.13280
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %% [markdown]
# Histograms that show the distribution in values for 'Area (mean)' for both benign and malignant tumors

# %%
sns.distplot(a=cancer_b_data['Area (mean)'], label="Benign", kde=False)
sns.distplot(a=cancer_m_data['Area (mean)'], label="Malignant", kde=False)
plt.legend()

# %% [markdown]
# Malignant tumors have higher values for 'Area (mean)', on average. Malignant tumors have a larger range of potential values.

# %% [markdown]
# ## 10.KDE Plot

# %% [markdown]
# #### Distribution in values for 'Radius (worst)' for both benign and malignant tumors

# %%
sns.distplot(a=cancer_b_data['Radius (worst)'], label="Benign", kde=True)
sns.distplot(a=cancer_m_data['Radius (worst)'], label="Malignant", kde=True)
plt.legend()
# Out:
# C:\Users\User1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# he algorithm is more likely to classify the tumor as malignant. This is because the curve for malignant tumors is much higher than the curve for benign tumors around a value of 25 -- and an algorithm that gets high accuracy is likely to make decisions based on this pattern in the data
